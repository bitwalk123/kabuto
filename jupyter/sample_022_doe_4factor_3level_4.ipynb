# %%
import pandas as pd
from statsmodels.formula.api import ols
import statsmodels.api as sm

# データ読み込み
df = pd.read_csv("../logs/result_20251201162005.csv")

# RSM用に因子を数値として扱う
factor_cols = ["PERIOD_MA_1","PERIOD_MA_2","PERIOD_MR","THRESHOLD_MR"]

# 二次回帰モデル（主効果＋二次項＋交互作用）
formula = (
    "total ~ PERIOD_MA_1 + PERIOD_MA_2 + PERIOD_MR + THRESHOLD_MR "
    "+ I(PERIOD_MA_1**2) + I(PERIOD_MA_2**2) + I(PERIOD_MR**2) + I(THRESHOLD_MR**2) "
    "+ PERIOD_MA_1:PERIOD_MA_2 + PERIOD_MR:THRESHOLD_MR"
)

model = ols(formula, data=df).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  total   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     11.79
# Date:                Tue, 02 Dec 2025   Prob (F-statistic):           2.25e-16
# Time:                        08:51:01   Log-Likelihood:                -1107.9
# No. Observations:                 243   AIC:                             2238.
# Df Residuals:                     232   BIC:                             2276.
# Df Model:                          10
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# Intercept                  35.5926     22.968      1.550      0.123      -9.660      80.845
# PERIOD_MA_1                -0.0023      0.459     -0.005      0.996      -0.907       0.903
# PERIOD_MA_2                -0.2327      0.046     -5.066      0.000      -0.323      -0.142
# PERIOD_MR                  -0.8407      0.890     -0.944      0.346      -2.595       0.913
# THRESHOLD_MR               14.0000      3.297      4.247      0.000       7.505      20.495
# I(PERIOD_MA_1 ** 2)        -0.0010      0.004     -0.276      0.783      -0.008       0.006
# I(PERIOD_MA_2 ** 2)         0.0002   3.58e-05      4.655      0.000     9.6e-05       0.000
# I(PERIOD_MR ** 2)           0.0090      0.014      0.627      0.531      -0.019       0.037
# I(THRESHOLD_MR ** 2)       -1.0988      0.358     -3.073      0.002      -1.803      -0.394
# PERIOD_MA_1:PERIOD_MA_2     0.0001      0.000      0.517      0.606      -0.000       0.001
# PERIOD_MR:THRESHOLD_MR     -0.0123      0.051     -0.244      0.807      -0.112       0.087
# ==============================================================================
# Omnibus:                       19.501   Durbin-Watson:                   2.567
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               27.870
# Skew:                           0.531   Prob(JB):                     8.87e-07
# Kurtosis:                       4.274   Cond. No.                     7.82e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.82e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
