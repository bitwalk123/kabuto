# %% [markdown]
# # 日経平均株価 15分足

# %% [markdown]
# ### 一つ上のディレクトリをパスに追加

# %%
import sys

path_up = ".."
if not path_up in sys.path:
    sys.path.append(path_up)

# %% [markdown]
# ### ライブラリをここで一括インポート

# %%
import datetime

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import mplfinance as mpf
import numpy as np
import pandas as pd
import yfinance as yf

from funcs.commons import get_name_15min_chart, get_name_15min_chart_usd

# %% [markdown]
# ## yfinance による株価データの取得

# %%
code = "N225"
symbol = f"^{code}"
ticker1 = yf.Ticker(symbol)
df = ticker1.history(period="1d", interval="15m")
df
# Out:
#                                    Open          High           Low  \
# Datetime
# 2025-12-26 09:00:00+09:00  50527.128906  50774.238281  50527.128906
# 2025-12-26 09:15:00+09:00  50702.378906  50802.250000  50646.871094
# 2025-12-26 09:30:00+09:00  50770.210938  50887.898438  50738.171875
# 2025-12-26 09:45:00+09:00  50872.308594  50878.488281  50774.070312
# 2025-12-26 10:00:00+09:00  50773.339844  50875.339844  50727.648438
# 2025-12-26 10:15:00+09:00  50861.191406  50889.210938  50856.269531
#
#                                   Close  Volume  Dividends  Stock Splits
# Datetime
# 2025-12-26 09:00:00+09:00  50697.210938       0        0.0           0.0
# 2025-12-26 09:15:00+09:00  50771.339844       0        0.0           0.0
# 2025-12-26 09:30:00+09:00  50874.718750       0        0.0           0.0
# 2025-12-26 09:45:00+09:00  50775.558594       0        0.0           0.0
# 2025-12-26 10:00:00+09:00  50861.968750       0        0.0           0.0
# 2025-12-26 10:15:00+09:00  50873.941406       0        0.0           0.0

# %% [markdown]
# ### ザラ場の時間範囲

# %%
dt_start = df.index[0]
dt_end = pd.to_datetime(
    f"{dt_start.year:04d}-{dt_start.month:02d}-{dt_start.day:02d} 15:30:00+09:00"
).tz_convert("Asia/Tokyo")
dt_start, dt_end
# Out:
# (Timestamp('2025-12-26 09:00:00+0900', tz='Asia/Tokyo'),
#  Timestamp('2025-12-26 15:30:00+0900', tz='Asia/Tokyo'))

# %% [markdown]
# ## 前日終値の取得

# %%
# 過去一週間のデータを取得
td = datetime.timedelta(days=7)
dt_first = df.index[0]
dt_prev = dt_first - td
df_last = ticker1.history(interval="1d", start=str(dt_prev.date()))
print(df_last["Close"])
n = len(df_last)
lastclose = df_last[n - 2 : n - 1]["Close"].iloc[0]
# lastclose = 50168.11 # 12/15 終値
# 確認のため出力
df_last[n - 2 : n - 1]["Close"]
# Out:
# Date
# 2025-12-19 00:00:00+09:00    49507.210938
# 2025-12-22 00:00:00+09:00    50402.390625
# 2025-12-23 00:00:00+09:00    50412.871094
# 2025-12-24 00:00:00+09:00    50344.101562
# 2025-12-25 00:00:00+09:00    50407.789062
# 2025-12-26 00:00:00+09:00    50873.941406
# Name: Close, dtype: float64
# Date
# 2025-12-25 00:00:00+09:00    50407.789062
# Name: Close, dtype: float64

# %% [markdown]
# ### 当日始値 - 前日終値

# %%
delta_open = df.head(1)["Open"].iloc[0] - lastclose
print(f"{delta_open:+.2f}")
# Out:
# +119.34

# %% [markdown]
# ## ローソク足チャート（小さいサイズ）

# %%
FONT_PATH = "../fonts/RictyDiminished-Regular.ttf"
fm.fontManager.addfont(FONT_PATH)

# FontPropertiesオブジェクト生成（名前の取得のため）
font_prop = fm.FontProperties(fname=FONT_PATH)
font_prop.get_name()

plt.rcParams["font.family"] = font_prop.get_name()
plt.rcParams["font.size"] = 8

fig, ax = plt.subplots(figsize=(3, 1.8))

ax.axhline(y=lastclose, color="red", linewidth=0.75)
mpf.plot(
    df,
    type="candle",
    style="default",
    datetime_format="%H:%M",
    xrotation=0,
    update_width_config=dict(candle_linewidth=0.75),
    ax=ax,
)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.0f}"))
ax.set_ylabel("JPY")
ax.grid()

if "shortName" in ticker1.info:
    ax.set_title(f"{ticker1.info['shortName']} ({symbol})")
elif "longName" in ticker1.info:
    ax.set_title(f"{ticker1.info['longName']} ({symbol})")
else:
    ax.set_title(f"{symbol}")

plt.tight_layout()
plt.savefig(get_name_15min_chart(code, dt_first))
plt.show()

# %% [markdown]
# ## ドル円レートで換算

# %%
code2 = "USDJPY=X"
symbol2 = code2
ticker2 = yf.Ticker(symbol2)

# %% [markdown]
# ### 過去２日分のドル円レートの過去データを取得

# %%
# 15分足で過去 2 日分のデータを取得
df_exchange = ticker2.history(period="2d", interval="15m")
df_exchange.index = df_exchange.index.tz_convert("Asia/Tokyo")
df_exchange
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2025-12-25 09:00:00+09:00  155.858994  155.925995  155.837997  155.856003
# 2025-12-25 09:15:00+09:00  155.856003  155.932007  155.845993  155.897003
# 2025-12-25 09:30:00+09:00  155.895996  155.908005  155.792007  155.804993
# 2025-12-25 09:45:00+09:00  155.819000  155.917999  155.744995  155.792007
# 2025-12-25 10:00:00+09:00  155.798004  155.921997  155.768005  155.778000
# 2025-12-25 10:15:00+09:00  155.822006  155.889999  155.763000  155.822006
# 2025-12-25 10:30:00+09:00  155.824997  155.871994  155.759003  155.766998
# 2025-12-25 10:45:00+09:00  155.766998  155.848007  155.720993  155.733994
# 2025-12-25 11:00:00+09:00  155.733994  155.858002  155.727005  155.787003
# 2025-12-25 11:15:00+09:00  155.806000  155.839996  155.677002  155.744003
# 2025-12-25 11:30:00+09:00  155.774994  155.830002  155.692001  155.796005
# 2025-12-25 11:45:00+09:00  155.817993  155.820007  155.725006  155.776993
# 2025-12-25 12:00:00+09:00  155.779007  155.817993  155.703995  155.787994
# 2025-12-25 12:15:00+09:00  155.792007  155.800003  155.664001  155.684006
# 2025-12-25 12:30:00+09:00  155.727997  155.755997  155.664001  155.718002
# 2025-12-25 12:45:00+09:00  155.688004  155.761993  155.660004  155.697998
# 2025-12-25 13:00:00+09:00  155.723007  155.750000  155.576996  155.638000
# 2025-12-25 13:15:00+09:00  155.727005  155.828003  155.626999  155.682007
# 2025-12-25 13:30:00+09:00  155.682007  155.794006  155.664001  155.703003
# 2025-12-25 13:45:00+09:00  155.716003  155.804001  155.662003  155.729996
# 2025-12-25 14:00:00+09:00  155.699997  155.755005  155.643005  155.751999
# 2025-12-25 14:15:00+09:00  155.733994  155.750000  155.660995  155.746002
# 2025-12-25 14:30:00+09:00  155.710999  155.761993  155.686005  155.737000
# 2025-12-25 14:45:00+09:00  155.737000  155.834000  155.692001  155.792999
# 2025-12-25 15:00:00+09:00  155.792999  155.809998  155.707001  155.770004
# 2025-12-25 15:15:00+09:00  155.712006  155.841995  155.697998  155.764999
# 2025-12-25 15:30:00+09:00  155.802994  155.901001  155.699997  155.889999
# 2025-12-25 15:45:00+09:00  155.895004  155.968002  155.817001  155.837006
# 2025-12-25 16:00:00+09:00  155.837006  155.960999  155.824005  155.854996
# 2025-12-25 16:15:00+09:00  155.891006  155.942993  155.819000  155.863007
# 2025-12-25 16:30:00+09:00  155.886002  155.990005  155.824997  155.889999
# 2025-12-25 16:45:00+09:00  155.917007  156.070007  155.871994  156.046997
# 2025-12-25 17:00:00+09:00  155.998993  156.119995  155.791000  155.862000
# 2025-12-25 20:15:00+09:00  155.998993  155.998993  155.998993  155.998993
# 2025-12-26 03:00:00+09:00  155.731003  155.731003  155.690002  155.690002
# 2025-12-26 04:45:00+09:00  155.641998  155.654999  155.595993  155.598999
# 2025-12-26 05:00:00+09:00  155.598999  155.753998  155.598007  155.744995
# 2025-12-26 05:15:00+09:00  155.617996  155.740997  155.598007  155.621002
# 2025-12-26 05:30:00+09:00  155.621002  155.742996  155.598007  155.654999
# 2025-12-26 05:45:00+09:00  155.610992  155.740005  155.598007  155.701996
# 2025-12-26 06:00:00+09:00  155.598007  155.692001  155.593002  155.606995
# 2025-12-26 09:00:00+09:00  156.106003  156.272995  156.095993  156.192993
# 2025-12-26 09:15:00+09:00  156.186005  156.240005  156.123993  156.156006
# 2025-12-26 09:30:00+09:00  156.162003  156.253006  156.156998  156.220001
# 2025-12-26 09:45:00+09:00  156.218994  156.488007  156.216995  156.399994
# 2025-12-26 10:00:00+09:00  156.408997  156.438995  156.291000  156.369995
# 2025-12-26 10:15:00+09:00  156.376007  156.376999  156.197998  156.231003
# 2025-12-26 10:30:00+09:00  156.227997  156.235001  156.156006  156.169006
#
#                            Volume  Dividends  Stock Splits
# Datetime
# 2025-12-25 09:00:00+09:00       0        0.0           0.0
# 2025-12-25 09:15:00+09:00       0        0.0           0.0
# 2025-12-25 09:30:00+09:00       0        0.0           0.0
# 2025-12-25 09:45:00+09:00       0        0.0           0.0
# 2025-12-25 10:00:00+09:00       0        0.0           0.0
# 2025-12-25 10:15:00+09:00       0        0.0           0.0
# 2025-12-25 10:30:00+09:00       0        0.0           0.0
# 2025-12-25 10:45:00+09:00       0        0.0           0.0
# 2025-12-25 11:00:00+09:00       0        0.0           0.0
# 2025-12-25 11:15:00+09:00       0        0.0           0.0
# 2025-12-25 11:30:00+09:00       0        0.0           0.0
# 2025-12-25 11:45:00+09:00       0        0.0           0.0
# 2025-12-25 12:00:00+09:00       0        0.0           0.0
# 2025-12-25 12:15:00+09:00       0        0.0           0.0
# 2025-12-25 12:30:00+09:00       0        0.0           0.0
# 2025-12-25 12:45:00+09:00       0        0.0           0.0
# 2025-12-25 13:00:00+09:00       0        0.0           0.0
# 2025-12-25 13:15:00+09:00       0        0.0           0.0
# 2025-12-25 13:30:00+09:00       0        0.0           0.0
# 2025-12-25 13:45:00+09:00       0        0.0           0.0
# 2025-12-25 14:00:00+09:00       0        0.0           0.0
# 2025-12-25 14:15:00+09:00       0        0.0           0.0
# 2025-12-25 14:30:00+09:00       0        0.0           0.0
# 2025-12-25 14:45:00+09:00       0        0.0           0.0
# 2025-12-25 15:00:00+09:00       0        0.0           0.0
# 2025-12-25 15:15:00+09:00       0        0.0           0.0
# 2025-12-25 15:30:00+09:00       0        0.0           0.0
# 2025-12-25 15:45:00+09:00       0        0.0           0.0
# 2025-12-25 16:00:00+09:00       0        0.0           0.0
# 2025-12-25 16:15:00+09:00       0        0.0           0.0
# 2025-12-25 16:30:00+09:00       0        0.0           0.0
# 2025-12-25 16:45:00+09:00       0        0.0           0.0
# 2025-12-25 17:00:00+09:00       0        0.0           0.0
# 2025-12-25 20:15:00+09:00       0        0.0           0.0
# 2025-12-26 03:00:00+09:00       0        0.0           0.0
# 2025-12-26 04:45:00+09:00       0        0.0           0.0
# 2025-12-26 05:00:00+09:00       0        0.0           0.0
# 2025-12-26 05:15:00+09:00       0        0.0           0.0
# 2025-12-26 05:30:00+09:00       0        0.0           0.0
# 2025-12-26 05:45:00+09:00       0        0.0           0.0
# 2025-12-26 06:00:00+09:00       0        0.0           0.0
# 2025-12-26 09:00:00+09:00       0        0.0           0.0
# 2025-12-26 09:15:00+09:00       0        0.0           0.0
# 2025-12-26 09:30:00+09:00       0        0.0           0.0
# 2025-12-26 09:45:00+09:00       0        0.0           0.0
# 2025-12-26 10:00:00+09:00       0        0.0           0.0
# 2025-12-26 10:15:00+09:00       0        0.0           0.0
# 2025-12-26 10:30:00+09:00       0        0.0           0.0

# %% [markdown]
# ### 15分足の Close のドル円レートで一括割る

# %%
ser_rate = df_exchange.loc[df.index, "Close"]
ser_rate
df2 = pd.DataFrame()
df2["Open"] = df["Open"] / ser_rate
df2["High"] = df["High"] / ser_rate
df2["Low"] = df["Low"] / ser_rate
df2["Close"] = df["Close"] / ser_rate
df2
# Out:
#                                  Open        High         Low       Close
# Datetime
# 2025-12-26 09:00:00+09:00  323.491649  325.073726  323.491649  324.580571
# 2025-12-26 09:15:00+09:00  324.690547  325.330106  324.335083  325.132162
# 2025-12-26 09:30:00+09:00  324.991746  325.745091  324.786657  325.660724
# 2025-12-26 09:45:00+09:00  325.270528  325.310040  324.642406  324.651922
# 2025-12-26 10:00:00+09:00  324.700016  325.352315  324.407815  325.266805
# 2025-12-26 10:15:00+09:00  325.551206  325.730553  325.519702  325.632816

# %% [markdown]
# ### 前日の終値のドル円レートから、前日の終値のドル換算

# %%
dt = df_exchange.head(1).index[0]
dt_last_close = pd.to_datetime(f"{str(dt.date())} 15:15:00+09:00")
print(dt_last_close)
last_close_usd = df_exchange.loc[dt_last_close, "Close"]
last_close_usd
# Out:
# 2025-12-25 15:15:00+09:00
# np.float64(155.76499938964844)

# %% [markdown]
# ## ローソク足チャート（小さいサイズ）/ ドル換算チャート

# %%
FONT_PATH = "../fonts/RictyDiminished-Regular.ttf"
fm.fontManager.addfont(FONT_PATH)

# FontPropertiesオブジェクト生成（名前の取得のため）
font_prop = fm.FontProperties(fname=FONT_PATH)
font_prop.get_name()

plt.rcParams["font.family"] = font_prop.get_name()
plt.rcParams["font.size"] = 8

fig, ax = plt.subplots(figsize=(3, 1.8))

ax.axhline(y=lastclose / last_close_usd, color="red", linewidth=0.75)
print("前日終値（ドル換算）", lastclose / last_close_usd)
mpf.plot(
    df2,
    type="candle",
    style="default",
    datetime_format="%H:%M",
    xrotation=0,
    update_width_config=dict(candle_linewidth=0.75),
    ax=ax,
)
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
ax.set_ylabel("USD")
ax.grid()

if "shortName" in ticker1.info:
    ax.set_title(f"{ticker1.info['shortName']} ({symbol}) in USD")
elif "longName" in ticker1.info:
    ax.set_title(f"{ticker1.info['longName']} ({symbol}) in USD")
else:
    ax.set_title(f"{symbol}")

plt.tight_layout()
plt.savefig(get_name_15min_chart_usd(code, dt_first))
plt.show()
# Out:
# 前日終値（ドル換算） 323.6143502071616
