# %%
from collections import deque

# %%
deque_mad_signal = deque(maxlen=2)

# %%
deque_mad_signal.append(1)
deque_mad_signal.append(2)
deque_mad_signal
# Out:
# deque([1, 2], maxlen=2)

# %%
deque_mad_signal[-2]
# Out:
# 1
