# %%
import sys

path_up = ".."
if not path_up in sys.path:
    sys.path.append(path_up)

# %%
import json
import os

from structs.res import AppRes

# %%
res = AppRes()

# %%
code = "7011"
path_json = os.path.join("..", res.dir_info, f"{code}.json")
print(path_json)
dict_param = {
    "PERIOD_MA_1": 180,
    "PERIOD_MA_2": 300,
    "PERIOD_SLOPE": 5,
    "THRESHOLD_SLOPE": 0.5,
    "LOSSCUT_1": -25,
}
print(dict_param)
with open(path_json, "w") as f:
    json.dump(dict_param, f, indent=2)

with open(path_json) as f:
    print(json.load(f))
# Out:
# ../info/7011.json
# {'PERIOD_MA_1': 180, 'PERIOD_MA_2': 300, 'PERIOD_SLOPE': 5, 'THRESHOLD_SLOPE': 0.5, 'LOSSCUT_1': -25}
# {'PERIOD_MA_1': 180, 'PERIOD_MA_2': 300, 'PERIOD_SLOPE': 5, 'THRESHOLD_SLOPE': 0.5, 'LOSSCUT_1': -25}
