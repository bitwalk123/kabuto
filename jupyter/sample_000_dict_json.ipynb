# %%
import sys

path_up = ".."
if not path_up in sys.path:
    sys.path.append(path_up)

# %%
import json
import os

from structs.res import AppRes

# %%
res = AppRes()

# %%
code = "7011"
path_json = os.path.join("..", res.dir_info, f"{code}.json")
print(path_json)
dict_param = {
    "PERIOD_MA_1": 75,
    "PERIOD_MA_2": 540,
    "PERIOD_MR": 30,
    "THRESHOLD_MR": 7,
}
print(dict_param)
with open(path_json, "w") as f:
    json.dump(dict_param, f, indent=2)

with open(path_json) as f:
    print(json.load(f))
# Out:
# ../info/7011.json
# {'PERIOD_MA_1': 75, 'PERIOD_MA_2': 540, 'PERIOD_MR': 30, 'THRESHOLD_MR': 7}
# {'PERIOD_MA_1': 75, 'PERIOD_MA_2': 540, 'PERIOD_MR': 30, 'THRESHOLD_MR': 7}

# %%
code = "8306"
path_json = os.path.join("..", res.dir_info, f"{code}.json")
print(path_json)
dict_param = {
    "PERIOD_MA_1": 60,
    "PERIOD_MA_2": 600,
    "PERIOD_MR": 30,
    "THRESHOLD_MR": 3.5,
}
print(dict_param)
with open(path_json, "w") as f:
    json.dump(dict_param, f, indent=2)

with open(path_json) as f:
    print(json.load(f))
# Out:
# ../info/8306.json
# {'PERIOD_MA_1': 60, 'PERIOD_MA_2': 600, 'PERIOD_MR': 30, 'THRESHOLD_MR': 3.5}
# {'PERIOD_MA_1': 60, 'PERIOD_MA_2': 600, 'PERIOD_MR': 30, 'THRESHOLD_MR': 3.5}
