# %%
import sys

path_up = ".."
if not path_up in sys.path:
    sys.path.append(path_up)

# %%
import os
import re

import pandas as pd

from modules.rl_ppo_lite_v1 import train_on_day

# %%
out = "result.csv"
if os.path.exists(out):
    df = pd.read_csv(out)
else:
    df = pd.DataFrame({
        "Date": [],
        "Code": [],
        "Profit": [],
        "Trades": [],
    })
    df = df.astype(object)
print(df)
# Out:
# Empty DataFrame
# Columns: [Date, Code, Profit, Trades]
# Index: []

# %%
list_csv = [
    "list_item/tick_20250602_7011.csv",
    "list_item/tick_20250603_7011.csv",
    "list_item/tick_20250604_7011.csv",
    "list_item/tick_20250605_7011.csv",
    "list_item/tick_20250606_7011.csv",
    "list_item/tick_20250609_7011.csv",
    "list_item/tick_20250610_7011.csv",
    "list_item/tick_20250611_7011.csv",
    "list_item/tick_20250612_7011.csv",
    "list_item/tick_20250613_7011.csv",
    "list_item/tick_20250617_7011.csv",
    "list_item/tick_20250618_7011.csv",
    "list_item/tick_20250619_7011.csv",
    "list_item/tick_20250620_7011.csv",
    "list_item/tick_20250623_7011.csv",
    "list_item/tick_20250624_7011.csv",
    "list_item/tick_20250625_7011.csv",
    "list_item/tick_20250626_7011.csv",
    "list_item/tick_20250627_7011.csv",
    "list_item/tick_20250630_7011.csv",
    "list_item/tick_20250701_7011.csv",
    "list_item/tick_20250702_7011.csv",
    "list_item/tick_20250703_7011.csv",
    "list_item/tick_20250704_7011.csv",
    "list_item/tick_20250707_7011.csv",
    "list_item/tick_20250708_7011.csv",
    "list_item/tick_20250709_7011.csv",
    "list_item/tick_20250710_7011.csv",
    "list_item/tick_20250711_7011.csv",
    "list_item/tick_20250714_7011.csv",
    "list_item/tick_20250715_7011.csv",
    "list_item/tick_20250716_7011.csv",
    "list_item/tick_20250717_7011.csv",
    "list_item/tick_20250718_7011.csv",
    "list_item/tick_20250722_7011.csv",
    "list_item/tick_20250723_7011.csv",
    "list_item/tick_20250724_7011.csv",
    "list_item/tick_20250725_7011.csv",
    "list_item/tick_20250728_7011.csv",
    "list_item/tick_20250729_7011.csv",
    "list_item/tick_20250730_7011.csv",
    "list_item/tick_20250731_7011.csv",
    "list_item/tick_20250801_7011.csv",
    "list_item/tick_20250804_7011.csv",
    "list_item/tick_20250805_7011.csv",
    "list_item/tick_20250806_7011.csv",
    "list_item/tick_20250807_7011.csv",
    "list_item/tick_20250808_7011.csv",
    "list_item/tick_20250812_7011.csv",
    "list_item/tick_20250813_7011.csv",
    "list_item/tick_20250814_7011.csv",
    "list_item/tick_20250815_7011.csv",
]
model = "models/7011_ac.pt"
pattern = re.compile(r".+([0-9]{4})([0-9]{2})([0-9]{2})_([0-9A-Z]{4})\.csv")
for csv in list_csv:
    m = pattern.match(csv)
    if m:
        yyyy = m.group(1)
        mm = m.group(2)
        dd = m.group(3)
        code = m.group(4)
    else:
        yyyy = "1970"
        mm = "01"
        dd = "01"
        code = "0000"
    dt = pd.to_datetime(f"{yyyy}-{mm}-{dd}")
    rewards, trade_counts, pnl, ntrades, trades_detail = train_on_day(
        csv,
        model_path=model,
        epochs=1,
        window=50,
        device="cpu",
    )
    print(dt, code, rewards[0], ntrades)
    r = len(df)
    df.at[r, "Date"] = dt
    df.at[r, "Code"] = code
    df.at[r, "Profit"] = rewards[0]
    df.at[r, "Trades"] = ntrades
    # 再学習（10回）
    train_on_day(
        csv,
        model_path=model,
        epochs=10,
        window=50,
        device="cpu",
    )

print(df)
df.to_csv(out, index=False)
# Out:
# /opt/storage1/bitwalk/MyProjects/kabuto/samples/../modules/rl.py:144: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   obs = torch.tensor(
# Epoch 1/1: Reward=-7300 JPY, Trades=1381
# Saved weights to ../models/7011_ac.pt
# 2025-06-02 00:00:00 7011 -7300.0 1373
# Loading existing weights from ../models/7011_ac.pt
# Epoch 1/10: Reward=-7500 JPY, Trades=1418
# Epoch 2/10: Reward=-4400 JPY, Trades=1382
# Epoch 3/10: Reward=7900 JPY, Trades=1390
# Epoch 4/10: Reward=2300 JPY, Trades=1444
# Epoch 5/10: Reward=9800 JPY, Trades=1362
# Epoch 6/10: Reward=-100 JPY, Trades=1319
# Epoch 7/10: Reward=9700 JPY, Trades=1188
# Epoch 8/10: Reward=6500 JPY, Trades=1176
# Epoch 9/10: Reward=8200 JPY, Trades=1129
# Epoch 10/10: Reward=16600 JPY, Trades=1075
# ...
