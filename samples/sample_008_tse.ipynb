# %% [markdown]
# # 日本取引所グループ (JPX) から上場銘柄リストを取得

# %%
import sys
path_up = '..'
if not path_up in sys.path:
    sys.path.append(path_up)

# %%
from funcs.tse import get_ticker_list, get_ticker_name_list

# %%
df = get_ticker_list()
df
# Out:
#             日付   コード                銘柄名       市場・商品区分 33業種コード  33業種区分 17業種コード  \
# 0     20250530  1301                 極洋    プライム（内国株式）      50  水産・農林業       1
# 1     20250530  130A  Ｖｅｒｉｔａｓ　Ｉｎ　Ｓｉｌｉｃｏ    グロース（内国株式）    3250     医薬品       5
# 2     20250530  1332               ニッスイ    プライム（内国株式）      50  水産・農林業       1
# 3     20250530  1333             マルハニチロ    プライム（内国株式）      50  水産・農林業       1
# 4     20250530  135A     ＶＲＡＩＮ　Ｓｏｌｕｔｉｏｎ    グロース（内国株式）    5250  情報・通信業      10
# ...        ...   ...                ...           ...     ...     ...     ...
# 3809  20250530  9991               ジェコス    プライム（内国株式）    6050     卸売業      13
# 3810  20250530  9993               ヤマザワ  スタンダード（内国株式）    6100     小売業      14
# 3811  20250530  9994                やまや  スタンダード（内国株式）    6100     小売業      14
# 3812  20250530  9996              サトー商会  スタンダード（内国株式）    6050     卸売業      13
# 3813  20250530  9997               ベルーナ    プライム（内国株式）    6100     小売業      14
#
# ...

# %%
list_ticker = ["7011", "7203", "8306"]
get_ticker_name_list(list_ticker)
# Out:
# ['三菱重工業', 'トヨタ自動車', '三菱ＵＦＪフィナンシャル・グループ']
